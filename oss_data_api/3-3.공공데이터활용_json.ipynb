# %% [markdown]
# # 화장품 업체 정보

# %%
from dotenv import load_dotenv
import os
from pathlib import Path

# .env 파일에 예: PUBLIC_DATA_KEY=your_key

env_path = Path('.') / '.env'
load_dotenv(dotenv_path=env_path, override=True)

PUBLIC_DATA_KEY = os.getenv("PUBLIC_DATA_KEY")
if PUBLIC_DATA_KEY is None:
    raise RuntimeError("PUBLIC_DATA_KEY가 .env에 없습니다.")
# PUBLIC_DATA_KEY

# %%
import requests

url = 'http://apis.data.go.kr/1471000/CsmtcsMfcrtrInfoService01/getCsmtcsMfcrtrInfoList01'
# params ={'serviceKey' : PUBLIC_DATA_KEY, 'entp_name' : '', 'entp_permit_date' : '', 'pageNo' : '1', 'numOfRows' : '3', 'type' : 'json' }
params ={'serviceKey' : PUBLIC_DATA_KEY, 'entp_name' : '아이꿈(iQoom)', 'pageNo' : '1', 'numOfRows' : '3', 'type' : 'json' }

response = requests.get(url, params=params)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}, 'body': {'pageNo': 1, 'totalCount': 2, 'numOfRows': 3, 'items': [{'INDUTY': '화장품제조', 'ENTP_SEQ': '2024005168', 'ENTP_NAME': '아이꿈(iQoom)', 'BOSS_NAME': '양혜정', 'ENTP_PERMIT_DATE': '20240419', 'FACTORY_ADDR': '대전광역시 서구 복수남로36번길 441층 101호', 'BIZRNO': '1233965096'}, {'INDUTY': '화장품책임판매', 'ENTP_SEQ': '2024007526', 'ENTP_NAME': '아이꿈(iQoom)', 'BOSS_NAME': '양혜정', 'ENTP_PERMIT_DATE': '20240613', 'FACTORY_ADDR': '대전광역시 서구 복수남로36번길 441층 101호', 'BIZRNO': '1233965096'}]}}
