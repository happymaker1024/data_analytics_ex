# %%
import pandas as pd
df = pd.read_csv("naver_news/2025-11-17-15.csv")
df.head()
# Out:
#                                                 헤드라인     신문사  \
# 0                 김민석, 대학생들과 '천원의 아침밥'…"내년 지원 대폭 확대"     더팩트
# 1                '관봉권·쿠팡 의혹' 안권섭 특검 "맡겨진 소임 최선 다할 것"    TV조선
# 2  李 대통령 지지율 54.5%, 3주 만에 감소⋯"'대장동 항소포기' 주된 요인" [...  아이뉴스24
# 3              통상대응 예산 7000억, 목적 예비비로…'여야 합의' 기재위 의결   머니투데이
# 4    "단식한다던 이재명, 밤이면 사무실로.. 중증 내로남불" 이준석, 헌법존중TF 맹비난  파이낸셜뉴스
#
#                                               이미지url
# 0  https://mimgnews.pstatic.net/image/origin/629/...
# 1  https://mimgnews.pstatic.net/image/origin/448/...
# 2  https://mimgnews.pstatic.net/image/origin/031/...
# 3  https://mimgnews.pstatic.net/image/origin/008/...
# 4  https://mimgnews.pstatic.net/image/origin/014/...
